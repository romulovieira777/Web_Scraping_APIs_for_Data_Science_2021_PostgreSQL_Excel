# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'x-kl-ajax-request': 'Ajax_Request',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'x-autolist-session-guid': 'ec835ee8-0216-4854-88fe-c3972deb0f68',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-ch-ua': '^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk3LjAuNDY5Mi45OSBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=9997f6b3-f82f-48f1-b300-2e82b607661f.1643289849684; scavenger-a493=...; _sp_ses.8ca5=*; g_state=^{^\\^i_p^\\^:1643297148538,^\\^i_l^\\^:1^}; sp-nuid=65a0a5b2-10cd-4cd1-a685-8293ebf227e0; _sp_id.8ca5=d7b038a1-56d3-4be7-87bd-294a686c74da.1643289850.1.1643290282.1643289850.f20f312b-3c35-48eb-841b-4b783078da7f',
    'sec-gpc': '1',
    'if-none-match': 'W/^\\^c34461c76cb19b78cdef626f7c0c6079^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'S^%%5EC3^%%5EA3o^%%5E20Paulo,^%%5E20SP'),
    ('latitude', '-23.6283'),
    ('longitude', '-46.6409'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'total_results_count': 385,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=-23.6283&location=S%5E%25%255EC3%5E%25%255EA3o%5E%25%255E20Paulo%2C%5E%25%255E20SP&longitude=-46.6409&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1642657502,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB2LF647875',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2LF647875',
#    'clickoff_url': 'https://www.carmax.com/car/21676488?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
# ...

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1642657502,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EB2LF647875',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2LF647875',
#   'clickoff_url': 'https://www.carmax.com/car/21676488?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 235652559,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21676488/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4RWLmo9_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21676488/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 32.843399,
#   'lon': -96.898399,
#   'year': 2020,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$51,998',
#   'price_unformatted': 51998,
# ...

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
results_items = results_json['search_results']

# %%
# starting point for first result
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1642657502,
#  'recent_price_drop': True,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EB2LF647875',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2LF647875',
#  'clickoff_url': 'https://www.carmax.com/car/21676488?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 235652559,
#  'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21676488/1.jpg?width=1024&watermark=LYCG_1a',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4RWLmo9_--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21676488/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#  'lat': 32.843399,
#  'lon': -96.898399,
#  'year': 2020,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$51,998',
#  'price_unformatted': 51998,
#  'mileage': '25,813 Miles',
# ...

# %%
# model
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
# mileage
results_json['search_results'][0]['mileage']
# Out:
# '25,813 Miles'

# %%
# year
results_json['search_results'][0]['year']
# Out:
# 2020

# %%
# dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'CarMax Texas Stadium (Irving) - Now Offering Curbside Pickup And Home Delivery'

# %%
# price
results_json['search_results'][0]['price']
# Out:
# '$51,998'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in results_items:
    
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['mileage'])
    
    # year
    year.append(result['year'])
    
    # dealer_name
    dealer_name.append(result['dealer_name'])
    
    # price
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
tesla_df = pd.DataFrame({'model': model, 'Mileage': mileage, 'Year': year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_df
# Out:
#       model       Mileage  Year  \
# 0   Model 3  25,813 Miles  2020
# 1   Model 3   8,261 Miles  2021
# 2   Model 3   9,330 Miles  2021
# 3   Model 3  13,356 Miles  2018
# 4   Model Y  28,656 Miles  2020
# 5   Model 3   2,097 Miles  2021
# 6   Model Y  11,355 Miles  2021
# 7   Model 3   7,645 Miles  2021
# 8   Model 3   8,908 Miles  2021
# 9   Model 3   7,604 Miles  2021
# 10  Model 3  21,657 Miles  2020
# 11  Model S  31,061 Miles  2018
# 12  Model 3  12,236 Miles  2020
# 13  Model 3   2,400 Miles  2021
# 14  Model 3   3,921 Miles  2021
# 15  Model 3   4,368 Miles  2021
# 16  Model Y   3,300 Miles  2021
# 17  Model 3   9,006 Miles  2020
# 18  Model Y  17,120 Miles  2020
# 19  Model 3  13,834 Miles  2021
#
#                                           Dealer Name    Price
# 0   CarMax Texas Stadium (Irving) - Now Offering C...  $51,998
# 1   CarMax Palmdale - Now Offering Curbside Pickup...  $63,998
# 2   CarMax Boise (Meridian) - Now Offering Curbsid...  $51,998
# ...

# %%
tesla_df.to_csv('tesla_single_page.xlsx', index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'x-kl-ajax-request': 'Ajax_Request',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'x-autolist-session-guid': 'ec835ee8-0216-4854-88fe-c3972deb0f68',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-ch-ua': '^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk3LjAuNDY5Mi45OSBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=9997f6b3-f82f-48f1-b300-2e82b607661f.1643289849684; scavenger-a493=...; _sp_ses.8ca5=*; g_state=^{^\\^i_p^\\^:1643297148538,^\\^i_l^\\^:1^}; sp-nuid=65a0a5b2-10cd-4cd1-a685-8293ebf227e0; _sp_id.8ca5=d7b038a1-56d3-4be7-87bd-294a686c74da.1643289850.1.1643290282.1643289850.f20f312b-3c35-48eb-841b-4b783078da7f',
    'sec-gpc': '1',
    'if-none-match': 'W/^\\^c34461c76cb19b78cdef626f7c0c6079^\\^',
}

model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1, 6):
    params = (
        ('make', 'Tesla'),
        ('location', 'S^%%5EC3^%%5EA3o^%%5E20Paulo,^%%5E20SP'),
        ('latitude', '-23.6283'),
        ('longitude', '-46.6409'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    # response variable for the get request
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (20 items for each page)
    result_items = results_json['search_results']
    
    for result in results_items:
    
        # model
        model.append(result['model'])

        # mileage
        mileage.append(result['mileage'])

        # year
        year.append(result['year'])

        # dealer_name
        dealer_name.append(result['dealer_name'])

        # price
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'model': model, 'Mileage': mileage, 'Year': year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_multiple_df
# Out:
#       model       Mileage  Year  \
# 0   Model 3  25,813 Miles  2020
# 1   Model 3   8,261 Miles  2021
# 2   Model 3   9,330 Miles  2021
# 3   Model 3  13,356 Miles  2018
# 4   Model Y  28,656 Miles  2020
# ..      ...           ...   ...
# 95  Model 3   4,368 Miles  2021
# 96  Model Y   3,300 Miles  2021
# 97  Model 3   9,006 Miles  2020
# 98  Model Y  17,120 Miles  2020
# 99  Model 3  13,834 Miles  2021
#
#                                           Dealer Name    Price
# 0   CarMax Texas Stadium (Irving) - Now Offering C...  $51,998
# 1   CarMax Palmdale - Now Offering Curbside Pickup...  $63,998
# 2   CarMax Boise (Meridian) - Now Offering Curbsid...  $51,998
# 3   CarMax Columbus Sawmill - Now Offering Curbsid...  $44,998
# 4   CarMax Capital Boulevard - Now Offering Curbsi...  $61,998
# ..                                                ...      ...
# 95  CarMax Clearwater - Now Offering Curbside Pick...  $51,998
# 96    CarMax Clackamas - Now Offering Curbside Pickup  $77,998
# ...

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multiple_df.to_csv('tesla_multiple_pages.xlsx', index=False)
