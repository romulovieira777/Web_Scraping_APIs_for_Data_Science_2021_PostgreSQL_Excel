# %% [markdown]
# #### Step 1 - Imports

# %%
import requests

# %% [markdown]
# #### Step 2 - Request & CURL

# %%
headers = {
    'authority': 'www.behance.net',
    'x-kl-ajax-request': 'Ajax_Request',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
    'accept': '*/*',
    'x-bcp': 'bfcbf186-ff42-4b9c-ba2a-8cf3ca2cb690',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-ch-ua': '^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
    'cookie': 'gk_suid=53192166; gki=^%^7B^%^22feature_stock_rail^%^22^%^3Afalse^%^7D; bcp=bfcbf186-ff42-4b9c-ba2a-8cf3ca2cb690; AMCVS_9E1005A551ED61CA0A490D45^%^40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; feds_privacy_consent=^{^\\^hasUserProvidedConsent^\\^:true,^\\^userHasCustomConsent^\\^:false^}; AMCV_9E1005A551ED61CA0A490D45^%^40AdobeOrg=870038026^%^7CMCMID^%^7C86810679775466113852269539934356177120^%^7CMCAAMLH-1643987617^%^7C4^%^7CMCAAMB-1643987617^%^7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y^%^7CMCOPTOUT-1643390017s^%^7CNONE^%^7CMCAID^%^7CNONE^%^7CMCCIDH^%^7C-869195863^%^7CvVersion^%^7C5.0.0; sign_up_prompt=true; s_sq=^%^5B^%^5BB^%^5D^%^5D; s_ppv=^[^%^22www.behance.net/^%^22^%^2C100^%^2C0^%^2C58510^%^2C330^%^2C663^%^2C1366^%^2C768^%^2C1^%^2C^%^22L^%^22^]; ilo0=true; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jan+28+2022+12^%^3A22^%^3A08+GMT-0300+(Hor^%^C3^%^A1rio+Padr^%^C3^%^A3o+de+Bras^%^C3^%^ADlia)&version=6.9.0&hosts=&consentId=1c61f996-0091-4d24-bfe5-2f09487b1522&interactionCount=1&landingPath=NotLandingPage&groups=C0001^%^3A1^%^2CC0002^%^3A1^%^2CC0003^%^3A1^%^2CC0004^%^3A1&AwaitingReconsent=false',
    'sec-gpc': '1',
}

params = (
    ('content', 'projects'),
    ('field', 'architecture'),
    ('ordinal', '0'),
)

response = requests.get('https://www.behance.net/search', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['search', 'creativeFields', 'tools', 'schools'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
results_json['search']
# Out:
# {'filters': {'search': None,
#   'sort': 'recommended',
#   'time': 'week',
#   'field': 'architecture',
#   'color_hex': None,
#   'schools': None,
#   'tools': None,
#   'user_tags': None,
#   'country': None,
#   'state': None,
#   'city': None,
#   'stateCode': None},
#  'creativeFields': {'popular': [{'label': 'Architecture',
#     'value': 'architecture',
#     'id': 4},
#    {'label': 'Art Direction', 'value': 'art direction', 'id': 5},
#    {'label': 'Branding', 'value': 'branding', 'id': 109},
#    {'label': 'Fashion', 'value': 'fashion', 'id': 37},
#    {'label': 'Graphic Design', 'value': 'graphic design', 'id': 44},
#    {'label': 'Illustration', 'value': 'illustration', 'id': 48},
#    {'label': 'Industrial Design', 'value': 'industrial design', 'id': 49},
#    {'label': 'Interaction Design', 'value': 'interaction design', 'id': 51},
#    {'label': 'Motion Graphics', 'value': 'motion graphics', 'id': 63},
#    {'label': 'Photography', 'value': 'photography', 'id': 73},
#    {'label': 'UI/UX', 'value': 'ui/ux', 'id': 132},
#    {'label': 'Web Design', 'value': 'web design', 'id': 102}],
#   'alphabetized': [{'name': '#',
#     'entries': [{'label': '3D Art', 'value': '3d art', 'id': 145},
#      {'label': '3D Modeling', 'value': '3d modeling', 'id': 147},
#      {'label': '3D Motion', 'value': '3d motion', 'id': 149}]},
#    {'name': 'a',
#     'entries': [{'label': 'Advertising', 'value': 'advertising', 'id': 108},
#      {'label': 'Advertising Photography',
#       'value': 'advertising photography',
#       'id': 151},
#      {'label': 'Animation', 'value': 'animation', 'id': 3},
#      {'label': 'App Design', 'value': 'app design', 'id': 153},
#      {'label': 'Apparel', 'value': 'apparel', 'id': 155},
#      {'label': 'AR/VR', 'value': 'ar/vr', 'id': 141},
#      {'label': 'Architecture', 'value': 'architecture', 'id': 4},
#      {'label': 'Architecture Concept',
#       'value': 'architecture concept',
#       'id': 157},
#      {'label': 'Architecture Photography',
#       'value': 'architecture photography',
#       'id': 159},
#      {'label': 'Architecture Visualization',
#       'value': 'architecture visualization',
#       'id': 161},
#      {'label': 'Art Direction', 'value': 'art direction', 'id': 5},
#      {'label': 'Automotive Design', 'value': 'automotive design', 'id': 130}]},
#    {'name': 'b',
#     'entries': [{'label': 'Beauty Photography',
#       'value': 'beauty photography',
#       'id': 163},
#      {'label': 'Branding', 'value': 'branding', 'id': 109}]},
#    {'name': 'c',
#     'entries': [{'label': 'Calligraphy', 'value': 'calligraphy', 'id': 133},
#      {'label': 'CGI', 'value': 'cgi', 'id': 241},
#      {'label': 'Character Design', 'value': 'character design', 'id': 124},
#      {'label': 'Cinematography', 'value': 'cinematography', 'id': 12},
#      {'label': 'Collage', 'value': 'collage', 'id': 165},
#      {'label': 'Coloring', 'value': 'coloring', 'id': 167},
#      {'label': 'Comic', 'value': 'comic', 'id': 169},
#      {'label': 'Concept Art', 'value': 'concept art', 'id': 171},
#      {'label': 'Copywriting', 'value': 'copywriting', 'id': 19},
#      {'label': 'Costume Design', 'value': 'costume design', 'id': 20},
#      {'label': 'Crafts', 'value': 'crafts', 'id': 21},
#      {'label': 'Creative Direction', 'value': 'creative direction', 'id': 137},
#      {'label': 'Culinary Arts', 'value': 'culinary arts', 'id': 23}]},
#    {'name': 'd',
#     'entries': [{'label': 'Digital Art', 'value': 'digital art', 'id': 122},
#      {'label': 'Digital Painting', 'value': 'digital painting', 'id': 173},
#      {'label': 'Directing', 'value': 'directing', 'id': 28},
#      {'label': 'Drawing', 'value': 'drawing', 'id': 110}]},
#    {'name': 'e',
#     'entries': [{'label': 'Editing', 'value': 'editing', 'id': 31},
#      {'label': 'Editorial Design', 'value': 'editorial design', 'id': 32},
#      {'label': 'Environmental Graphics',
#       'value': 'environmental graphics',
#       'id': 175},
#      {'label': 'Exhibition Design', 'value': 'exhibition design', 'id': 36}]},
#    {'name': 'f',
#     'entries': [{'label': 'Fashion', 'value': 'fashion', 'id': 37},
#      {'label': 'Fashion Design', 'value': 'fashion design', 'id': 177},
#      {'label': 'Fashion Illustration',
#       'value': 'fashion illustration',
#       'id': 179},
#      {'label': 'Fashion Photography',
#       'value': 'fashion photography',
#       'id': 181},
#      {'label': 'Fashion Retouching', 'value': 'fashion retouching', 'id': 183},
#      {'label': 'Fashion Styling', 'value': 'fashion styling', 'id': 93},
#      {'label': 'Film', 'value': 'film', 'id': 38},
#      {'label': 'Fine Arts', 'value': 'fine arts', 'id': 112},
#      {'label': 'Flower Arrangement', 'value': 'flower arrangement', 'id': 185},
#      {'label': 'Food Photography', 'value': 'food photography', 'id': 187},
#      {'label': 'Food Styling', 'value': 'food styling', 'id': 189},
#      {'label': 'Furniture Design', 'value': 'furniture design', 'id': 40}]},
#    {'name': 'g',
#     'entries': [{'label': 'Game Design', 'value': 'game design', 'id': 41},
#      {'label': 'GIF Animation', 'value': 'gif animation', 'id': 191},
#      {'label': 'Graffiti', 'value': 'graffiti', 'id': 43},
#      {'label': 'Graphic Design', 'value': 'graphic design', 'id': 44}]},
#    {'name': 'i',
#     'entries': [{'label': 'Icon Design', 'value': 'icon design', 'id': 131},
#      {'label': 'Illustration', 'value': 'illustration', 'id': 48},
#      {'label': 'Industrial Design', 'value': 'industrial design', 'id': 49},
#      {'label': 'Infographic', 'value': 'infographic', 'id': 193},
#      {'label': 'Information Architecture',
#       'value': 'information architecture',
#       'id': 50},
#      {'label': 'Interaction Design', 'value': 'interaction design', 'id': 51},
#      {'label': 'Interior Design', 'value': 'interior design', 'id': 52}]},
#    {'name': 'j',
#     'entries': [{'label': 'Jewelry Design',
#       'value': 'jewelry design',
#       'id': 53}]},
#    {'name': 'l',
#     'entries': [{'label': 'Label Design', 'value': 'label design', 'id': 195},
#      {'label': 'Landscape Design', 'value': 'landscape design', 'id': 55},
#      {'label': 'Lettering', 'value': 'lettering', 'id': 197},
#      {'label': 'Logo Design', 'value': 'logo design', 'id': 199}]},
#    {'name': 'm',
#     'entries': [{'label': 'Makeup', 'value': 'makeup', 'id': 203},
#      {'label': 'Makeup Arts', 'value': 'makeup arts', 'id': 201},
#      {'label': 'Model Test Photography',
#       'value': 'model test photography',
#       'id': 205},
#      {'label': 'Modeling', 'value': 'modeling', 'id': 207},
#      {'label': 'Motion Graphics', 'value': 'motion graphics', 'id': 63},
#      {'label': 'Music', 'value': 'music', 'id': 64},
#      {'label': 'Music Packaging', 'value': 'music packaging', 'id': 209}]},
#    {'name': 'p',
#     'entries': [{'label': 'Packaging', 'value': 'packaging', 'id': 66},
#      {'label': 'Painting', 'value': 'painting', 'id': 67},
#      {'label': 'Paperworks', 'value': 'paperworks', 'id': 211},
#      {'label': 'Pattern Design', 'value': 'pattern design', 'id': 69},
#      {'label': 'Performing Arts', 'value': 'performing arts', 'id': 70},
#      {'label': 'Photography', 'value': 'photography', 'id': 73},
#      {'label': 'Photography Styling',
#       'value': 'photography styling',
#       'id': 213},
#      {'label': 'Photojournalism', 'value': 'photojournalism', 'id': 74},
#      {'label': 'Poster Design', 'value': 'poster design', 'id': 215},
#      {'label': 'Product Design', 'value': 'product design', 'id': 79},
#      {'label': 'Product Photography',
#       'value': 'product photography',
#       'id': 217},
#      {'label': 'Programming', 'value': 'programming', 'id': 123},
#      {'label': 'Projection Mapping', 'value': 'projection mapping', 'id': 219},
#      {'label': 'Props Design', 'value': 'props design', 'id': 221}]},
#    {'name': 'r',
#     'entries': [{'label': 'Retouching', 'value': 'retouching', 'id': 136}]},
#    {'name': 's',
#     'entries': [{'label': 'Sculpting', 'value': 'sculpting', 'id': 86},
#      {'label': 'Set Design', 'value': 'set design', 'id': 87},
#      {'label': 'Shoe Design', 'value': 'shoe design', 'id': 223},
#      {'label': 'Sketching', 'value': 'sketching', 'id': 225},
#      {'label': 'Sound Design', 'value': 'sound design', 'id': 118},
#      {'label': 'Storyboarding', 'value': 'storyboarding', 'id': 91},
#      {'label': 'Street Art', 'value': 'street art', 'id': 135},
#      {'label': 'Students', 'value': 'students', 'id': 143},
#      {'label': 'Styleframing', 'value': 'styleframing', 'id': 227},
#      {'label': 'Surface Design', 'value': 'surface design', 'id': 229}]},
#    {'name': 't',
#     'entries': [{'label': 'T-Shirt Design',
#       'value': 't-shirt design',
#       'id': 231},
#      {'label': 'Textile Design', 'value': 'textile design', 'id': 95},
#      {'label': 'Toy Design', 'value': 'toy design', 'id': 126},
#      {'label': 'Type Design', 'value': 'type design', 'id': 233},
#      {'label': 'Typography', 'value': 'typography', 'id': 97}]},
#    {'name': 'u', 'entries': [{'label': 'UI/UX', 'value': 'ui/ux', 'id': 132}]},
#    {'name': 'v',
#     'entries': [{'label': 'Visual Effects',
#       'value': 'visual effects',
#       'id': 120},
#      {'label': 'Visualization', 'value': 'visualization', 'id': 235}]},
#    {'name': 'w',
#     'entries': [{'label': 'Web Design', 'value': 'web design', 'id': 102},
#      {'label': 'Window Design', 'value': 'window design', 'id': 237},
#      {'label': 'Woodworking', 'value': 'woodworking', 'id': 239},
#      {'label': 'Writing', 'value': 'writing', 'id': 105}]}],
#   'isInitialized': True},
#  'isFetching': {'allResults': False,
#   'projects': False,
#   'images': False,
#   'users': False,
#   'collections': False,
#   'moodboards': False},
#  'isLoadingMore': False,
#  'isInitialized': True,
#  'hasMore': True,
#  'content': {'projects': [{'id': 99004135,
#     'name': 'NIK MIRUS - MOTION, DESIGN AND SPACE',
#     'published_on': 1592333243,
#     'created_on': 1592332430,
#     'modified_on': 1643360418,
#     'url': 'https://www.behance.net/gallery/99004135/NIK-MIRUS-MOTION-DESIGN-AND-SPACE',
#     'slug': 'NIK-MIRUS-MOTION-DESIGN-AND-SPACE',
#     'privacy': 'public',
#     'fields': ['Photography', 'Art Direction', 'Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/946fc499004135.Y3JvcCwxMTQ1LDg5NSwxMjcsMA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/946fc499004135.Y3JvcCwxMTQ1LDg5NSwxMjcsMA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/946fc499004135.Y3JvcCwxMTQ1LDg5NSwxMjcsMA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/946fc499004135.Y3JvcCwxMTQ1LDg5NSwxMjcsMA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/946fc499004135.Y3JvcCwxMTQ1LDg5NSwxMjcsMA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/946fc499004135.Y3JvcCwxMTQ1LDg5NSwxMjcsMA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/946fc499004135.Y3JvcCwxMTQ1LDg5NSwxMjcsMA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 407597,
#       'first_name': "L'",
#       'last_name': 'ÉLOI',
#       'username': 'leloi',
#       'city': 'Montreal',
#       'state': 'Quebec',
#       'country': 'Canada',
#       'location': 'Montreal, Quebec, Canada',
#       'company': 'Talent Agency & Production House',
#       'occupation': "L'ÉLOI",
#       'created_on': 1302721709,
#       'url': 'https://www.behance.net/leloi',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/4d6f83407597.5984d4418fbec.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/4d6f83407597.5984d4418fbec.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/4d6f83407597.5984d4418fbec.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/4d6f83407597.5984d4418fbec.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/4d6f83407597.5984d4418fbec.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/4d6f83407597.5984d4418fbec.jpg'},
#       'display_name': "L' ÉLOI",
#       'fields': ['Photography', 'Art Direction', 'Set Design'],
#       'has_default_image': 0,
#       'website': 'http://leloi.ca',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/a13b7fd11744fee787f0f973254ade53/126d81db-bdf4-45ee-a862-61b13e8a9f1c_rwc_128x0x2811x410x3200.jpg?h=84121377c2690773488b4643bb8921bb',
#       'has_premium_access': False,
#       'stats': {'followers': 15611,
#        'following': 257,
#        'comments': 8,
#        'appreciations': 74902,
#        'views': 952380}},
#      {'id': 27218710,
#       'first_name': 'Nik',
#       'last_name': 'Mirus',
#       'username': 'nikmirus',
#       'city': 'Montreal',
#       'state': 'Quebec',
#       'country': 'Canada',
#       'location': 'Montreal, Quebec, Canada',
#       'company': '',
#       'occupation': 'Photographer ',
#       'created_on': 1454604789,
#       'url': 'https://www.behance.net/nikmirus',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/21923527218710.5a78c1e214cf7.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/21923527218710.5a78c1e214cf7.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/21923527218710.5a78c1e214cf7.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/21923527218710.5a78c1e214cf7.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/21923527218710.5a78c1e214cf7.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/21923527218710.5a78c1e214cf7.png'},
#       'display_name': 'Nik Mirus',
#       'fields': ['Photography', 'Art Direction', 'Set Design'],
#       'has_default_image': 0,
#       'website': 'www.nikmirus.ca',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/191075f33aab598268010018567e077d/0db0353d-f84d-44a6-af7e-2a31100fab94_rwc_0x973x2000x250x2000.jpg?h=e2d74be11fb031035d51d26aedb28e41',
#       'has_premium_access': False,
#       'stats': {'followers': 5066,
#        'following': 7,
#        'comments': 0,
#        'appreciations': 28096,
#        'views': 364625}}],
#     'stats': {'views': 4565, 'appreciations': 315, 'comments': 16},
#     'conceived_on': 1592265600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1610114444,
#       'site': {'id': 14,
#        'parent_id': 7,
#        'name': 'Photography',
#        'key': 'photography',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-7.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': 'photographyserved.com',
#        'url': 'https://www.behance.net/galleries/photography/photography',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/photography.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/photography@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/photography@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/photography'},
#      {'featured_on': 1643360418,
#       'site': {'id': 295,
#        'parent_id': 0,
#        'name': 'Photoshop',
#        'key': 'photoshop',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/photoshop.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/Photoshop',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/photoshop.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/photoshop@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/photoshop@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/Photoshop'}],
#     'colors': [{'r': 252, 'g': 3, 'b': 1}]},
#    {'id': 135439455,
#     'name': 'GRAPH + Faulkner Browns',
#     'published_on': 1642589812,
#     'created_on': 1642589719,
#     'modified_on': 1643313649,
#     'url': 'https://www.behance.net/gallery/135439455/GRAPH-Faulkner-Browns',
#     'slug': 'GRAPH-Faulkner-Browns',
#     'privacy': 'public',
#     'fields': ['Architecture',
#      'Architecture Visualization',
#      'Landscape Design'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/617707135439455.Y3JvcCwzOTk5LDMxMjgsMCw0MzU.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/617707135439455.Y3JvcCwzOTk5LDMxMjgsMCw0MzU.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/617707135439455.Y3JvcCwzOTk5LDMxMjgsMCw0MzU.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/617707135439455.Y3JvcCwzOTk5LDMxMjgsMCw0MzU.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/617707135439455.Y3JvcCwzOTk5LDMxMjgsMCw0MzU.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/617707135439455.Y3JvcCwzOTk5LDMxMjgsMCw0MzU.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/617707135439455.Y3JvcCwzOTk5LDMxMjgsMCw0MzU.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 9937589,
#       'first_name': 'GRAPH',
#       'last_name': 'Visual Studio',
#       'username': 'graphbcn',
#       'city': 'Barcelona',
#       'state': '',
#       'country': 'Spain',
#       'location': 'Barcelona, Spain',
#       'company': 'Graph Visual Studio',
#       'occupation': 'Architectural Visualization Studio info@graph.cat',
#       'created_on': 1416847547,
#       'url': 'https://www.behance.net/graphbcn',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/d6b1879937589.5d84f631692ee.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/d6b1879937589.5d84f631692ee.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/d6b1879937589.5d84f631692ee.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/d6b1879937589.5d84f631692ee.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/d6b1879937589.5d84f631692ee.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/d6b1879937589.5d84f631692ee.jpg'},
#       'display_name': 'GRAPH Visual Studio',
#       'fields': ['Architecture', 'Digital Art', 'Illustration'],
#       'has_default_image': 0,
#       'website': 'http://www.graph.cat',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/98b70852b9927fa5fc729c1dd7bd9213/2247761d-32cf-47a1-a8b6-f601300b7af5_rwc_-2x47x3838x396x3838.jpg?h=fe88fdf5a2150b114440a2853412d315',
#       'has_premium_access': False,
#       'stats': {'followers': 2073,
#        'following': 142,
#        'comments': 15,
#        'appreciations': 5557,
#        'views': 44816}}],
#     'stats': {'views': 1081, 'appreciations': 216, 'comments': 9},
#     'conceived_on': 1642550400,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1643313649,
#       'site': {'id': 141,
#        'parent_id': 5,
#        'name': 'Architecture Visualization',
#        'key': 'ArcV',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 78, 'g': 84, 'b': 70}]},
#    {'id': 135303109,
#     'name': 'monochrome 2.0',
#     'published_on': 1642445354,
#     'created_on': 1642444907,
#     'modified_on': 1643313647,
#     'url': 'https://www.behance.net/gallery/135303109/monochrome-20',
#     'slug': 'monochrome-20',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Interior Design'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/ed9154135303109.Y3JvcCwxMTkyLDkzMywxMDMsMA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/ed9154135303109.Y3JvcCwxMTkyLDkzMywxMDMsMA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/ed9154135303109.Y3JvcCwxMTkyLDkzMywxMDMsMA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/ed9154135303109.Y3JvcCwxMTkyLDkzMywxMDMsMA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/ed9154135303109.Y3JvcCwxMTkyLDkzMywxMDMsMA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/ed9154135303109.Y3JvcCwxMTkyLDkzMywxMDMsMA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/ed9154135303109.Y3JvcCwxMTkyLDkzMywxMDMsMA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 27655890,
#       'first_name': 'roomdesignburo',
#       'last_name': '_',
#       'username': 'anastasyaz6410',
#       'city': 'Moscow',
#       'state': '',
#       'country': 'Russian Federation',
#       'location': 'Moscow, Russian Federation',
#       'company': 'roomdesignburo',
#       'occupation': 'architect',
#       'created_on': 1455143400,
#       'url': 'https://www.behance.net/anastasyaz6410',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/d4569e27655890.5fac2713795a7.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/d4569e27655890.5fac2713795a7.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/d4569e27655890.5fac2713795a7.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/d4569e27655890.5fac2713795a7.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/d4569e27655890.5fac2713795a7.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/d4569e27655890.5fac2713795a7.jpg'},
#       'display_name': 'roomdesignburo _',
#       'fields': ['Interior Design', 'Architecture', 'Interaction Design'],
#       'has_default_image': 0,
#       'website': 'https://www.instagram.com/roomdesignburo/',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/a89c48f0641b722de047879950be95e0/ada7d831-39ed-4d15-beb4-99a7b59332be_rwc_0x1913x5534x773x5534.jpg?h=fba3d40a4d5e68768d335615b7b33951',
#       'has_premium_access': False,
#       'stats': {'followers': 4209,
#        'following': 57,
#        'comments': 14,
#        'appreciations': 8287,
#        'views': 89266}}],
#     'stats': {'views': 963, 'appreciations': 186, 'comments': 4},
#     'conceived_on': 1642377600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1643313647,
#       'site': {'id': 30,
#        'parent_id': 5,
#        'name': 'Interior Design',
#        'key': 'interior',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': 'interiordesignserved.com',
#        'url': 'https://www.behance.net/galleries/architecture/interior-design',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 206, 'g': 171, 'b': 156}]},
#    {'id': 135280101,
#     'name': 'An Audible Silence',
#     'published_on': 1642530521,
#     'created_on': 1642427179,
#     'modified_on': 1643302843,
#     'url': 'https://www.behance.net/gallery/135280101/An-Audible-Silence',
#     'slug': 'An-Audible-Silence',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Illustration', '3D Art'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/6cb47d135280101.Y3JvcCwzNzgwLDI5NTYsMCww.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/6cb47d135280101.Y3JvcCwzNzgwLDI5NTYsMCww.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/6cb47d135280101.Y3JvcCwzNzgwLDI5NTYsMCww.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/6cb47d135280101.Y3JvcCwzNzgwLDI5NTYsMCww.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/6cb47d135280101.Y3JvcCwzNzgwLDI5NTYsMCww.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/6cb47d135280101.Y3JvcCwzNzgwLDI5NTYsMCww.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/6cb47d135280101.Y3JvcCwzNzgwLDI5NTYsMCww.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 4804557,
#       'first_name': 'Tomasz Artur',
#       'last_name': 'Bolek',
#       'username': 'TomaszBolek',
#       'city': 'Łódź',
#       'state': '',
#       'country': 'Poland',
#       'location': 'Łódź, Poland',
#       'company': '',
#       'occupation': '建築夢想家  |  The Architectural Dreamer',
#       'created_on': 1390568687,
#       'url': 'https://www.behance.net/TomaszBolek',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/7947384804557.5a136e162ac25.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/7947384804557.5a136e162ac25.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/7947384804557.5a136e162ac25.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/7947384804557.5a136e162ac25.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/7947384804557.5a136e162ac25.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/7947384804557.5a136e162ac25.jpg'},
#       'display_name': 'Tomasz Artur Bolek',
#       'fields': ['Illustration', '3D Art', 'Architecture'],
#       'has_default_image': 0,
#       'website': '',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/8d8491cecb7519f5525e38294d3aced9/8507eea6-5153-4947-bf10-08f88666b215_rwc_0x596x1920x242x1920.jpg?h=a260953f6a677a755bdc251c156f35b4',
#       'has_premium_access': False,
#       'stats': {'followers': 9730,
#        'following': 4,
#        'comments': 350,
#        'appreciations': 23597,
#        'views': 237107}}],
#     'stats': {'views': 1801, 'appreciations': 351, 'comments': 11},
#     'conceived_on': 1642377600,
#     'premium': 0,
#     'linked_asset_count': 1,
#     'linked_assets': [{'name': '3D models (.blend)',
#       'url': None,
#       'premium': 1}],
#     'features': [{'featured_on': 1643302843,
#       'site': {'id': 347,
#        'parent_id': 16,
#        'name': '3D Art',
#        'key': '3DA',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-16.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/3d-art/3d-art',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/3d-art.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/3d-art@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/3d-art@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/3d-art'}],
#     'colors': [{'r': 16, 'g': 16, 'b': 19}]},
#    {'id': 135729415,
#     'name': 'Golden Hour',
#     'published_on': 1642935588,
#     'created_on': 1642935426,
#     'modified_on': 1643243418,
#     'url': 'https://www.behance.net/gallery/135729415/Golden-Hour',
#     'slug': 'Golden-Hour',
#     'privacy': 'public',
#     'fields': ['Photography', 'Architecture', 'Digital Art'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/ccb6f8135729415.Y3JvcCw1NDc3LDQyODMsMCwxNTA0.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/ccb6f8135729415.Y3JvcCw1NDc3LDQyODMsMCwxNTA0.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/ccb6f8135729415.Y3JvcCw1NDc3LDQyODMsMCwxNTA0.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/ccb6f8135729415.Y3JvcCw1NDc3LDQyODMsMCwxNTA0.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/ccb6f8135729415.Y3JvcCw1NDc3LDQyODMsMCwxNTA0.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/ccb6f8135729415.Y3JvcCw1NDc3LDQyODMsMCwxNTA0.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/ccb6f8135729415.Y3JvcCw1NDc3LDQyODMsMCwxNTA0.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 171577437,
#       'first_name': 'Alexander',
#       'last_name': 'Schoenberg',
#       'username': 'alexschoenberg',
#       'city': 'Hamburg',
#       'state': '',
#       'country': 'Germany',
#       'location': 'Hamburg, Germany',
#       'company': '',
#       'occupation': 'Fotograf',
#       'created_on': 1530884799,
#       'url': 'https://www.behance.net/alexschoenberg',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/030a27171577437.611441507327f.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/030a27171577437.611441507327f.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/030a27171577437.611441507327f.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/030a27171577437.611441507327f.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/030a27171577437.611441507327f.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/030a27171577437.611441507327f.jpg'},
#       'display_name': 'Alexander Schoenberg',
#       'fields': ['Photography', 'Architecture', 'Illustration'],
#       'has_default_image': 0,
#       'website': 'https://alexander-schoenberg.de/',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/a94cbcab964a067f6b0906aaf803e7e3/9bf0acbd-28aa-4200-b22c-8c15d95aed03_rwc_-2x749x2000x239x2000.jpg?h=148374240e8f06007323bd78aada815a',
#       'has_premium_access': False,
#       'stats': {'followers': 10235,
#        'following': 150,
#        'comments': 1046,
#        'appreciations': 34236,
#        'views': 233961}}],
#     'stats': {'views': 2886, 'appreciations': 505, 'comments': 76},
#     'conceived_on': 1642896000,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1643243418,
#       'site': {'id': 1,
#        'name': 'Behance.net',
#        'key': 'net',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/site/favicon.ico',
#        'url': 'http://www.behance.net',
#        'domain': 'www.behance.net',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/network.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/network@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/network@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries'}],
#     'colors': [{'r': 7, 'g': 4, 'b': 2}]},
#    {'id': 135245787,
#     'name': 'flow house',
#     'published_on': 1642389368,
#     'created_on': 1642387362,
#     'modified_on': 1643225455,
#     'url': 'https://www.behance.net/gallery/135245787/flow-house',
#     'slug': 'flow-house',
#     'privacy': 'public',
#     'fields': ['Architecture', '3D Art', 'Architecture Visualization'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/8948f4135245787.Y3JvcCwxNDAwLDEwOTUsMCwyMDc.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/8948f4135245787.Y3JvcCwxNDAwLDEwOTUsMCwyMDc.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/8948f4135245787.Y3JvcCwxNDAwLDEwOTUsMCwyMDc.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/8948f4135245787.Y3JvcCwxNDAwLDEwOTUsMCwyMDc.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/8948f4135245787.Y3JvcCwxNDAwLDEwOTUsMCwyMDc.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/8948f4135245787.Y3JvcCwxNDAwLDEwOTUsMCwyMDc.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/8948f4135245787.Y3JvcCwxNDAwLDEwOTUsMCwyMDc.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 3876831,
#       'first_name': 'Ricardo',
#       'last_name': 'Canton',
#       'username': 'arca3d',
#       'city': 'São Paulo',
#       'state': '',
#       'country': 'Brazil',
#       'location': 'São Paulo, Brazil',
#       'company': 'arca3d',
#       'occupation': 'Architectural Visualization',
#       'created_on': 1382310934,
#       'url': 'https://www.behance.net/arca3d',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/3876831.53e55666052cf.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/3876831.53e55666052cf.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/3876831.53e55666052cf.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/3876831.53e55666052cf.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/3876831.53e55666052cf.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/3876831.53e55666052cf.jpg'},
#       'display_name': 'Ricardo Canton',
#       'fields': ['Architecture', 'Digital Art', 'Illustration'],
#       'has_default_image': 0,
#       'website': 'ricanton.cgsociety.org/',
#       'banner_image_url': '',
#       'has_premium_access': False,
#       'stats': {'followers': 8367,
#        'following': 264,
#        'comments': 278,
#        'appreciations': 21205,
#        'views': 213420}}],
#     'stats': {'views': 3022, 'appreciations': 527, 'comments': 21},
#     'conceived_on': 1642377600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1643225455,
#       'site': {'id': 141,
#        'parent_id': 5,
#        'name': 'Architecture Visualization',
#        'key': 'ArcV',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 20, 'g': 23, 'b': 19}]},
#    {'id': 127075565,
#     'name': 'Mural For LaBel Valette Festival. France 2021',
#     'published_on': 1631207038,
#     'created_on': 1631207035,
#     'modified_on': 1643225453,
#     'url': 'https://www.behance.net/gallery/127075565/Mural-For-LaBel-Valette-Festival-France-2021',
#     'slug': 'Mural-For-LaBel-Valette-Festival-France-2021',
#     'privacy': 'public',
#     'fields': ['Illustration', 'Architecture', 'Graphic Design'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/80f8f5127075565.Y3JvcCwxMTc4LDkyMiw2MDEsNTU3.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/80f8f5127075565.Y3JvcCwxMTc4LDkyMiw2MDEsNTU3.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/80f8f5127075565.Y3JvcCwxMTc4LDkyMiw2MDEsNTU3.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/80f8f5127075565.Y3JvcCwxMTc4LDkyMiw2MDEsNTU3.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/80f8f5127075565.Y3JvcCwxMTc4LDkyMiw2MDEsNTU3.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/80f8f5127075565.Y3JvcCwxMTc4LDkyMiw2MDEsNTU3.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/80f8f5127075565.Y3JvcCwxMTc4LDkyMiw2MDEsNTU3.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 3532787,
#       'first_name': 'Katerina',
#       'last_name': 'Voronina',
#       'username': 'KatVoronina',
#       'city': 'Berlin',
#       'state': '',
#       'country': 'Germany',
#       'location': 'Berlin, Germany',
#       'company': '',
#       'occupation': 'Illustrator, motion-designer, art-director',
#       'created_on': 1379278509,
#       'url': 'https://www.behance.net/KatVoronina',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/39d1df3532787.6099539b333e0.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/39d1df3532787.6099539b333e0.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/39d1df3532787.6099539b333e0.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/39d1df3532787.6099539b333e0.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/39d1df3532787.6099539b333e0.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/39d1df3532787.6099539b333e0.jpg'},
#       'display_name': 'Katerina Voronina',
#       'fields': ['Illustration', 'Animation', 'Drawing'],
#       'has_default_image': 0,
#       'website': 'https://katevoronina.com',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/4c07b402f6d605bf5f4d7e043d2ef708/5ebb8162-73de-4f94-b394-f9746aca054b_rwc_0x289x1920x282x1920.jpg?h=1e9aef939f5266afa40615c95f549a89',
#       'has_premium_access': False,
#       'stats': {'followers': 5737,
#        'following': 650,
#        'comments': 248,
#        'appreciations': 15017,
#        'views': 136662}}],
#     'stats': {'views': 1259, 'appreciations': 261, 'comments': 18},
#     'conceived_on': 1631145600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1643225453,
#       'site': {'id': 101,
#        'parent_id': 1,
#        'name': 'Surface Design',
#        'key': 'surfacedesign',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-1.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/illustration/surface-design',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/illustration.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/illustration@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/illustration@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/illustration'}],
#     'colors': [{'r': 187, 'g': 182, 'b': 51}]},
#    {'id': 127383873,
#     'name': 'BRISE SOLEIL HOUSE',
#     'published_on': 1631638741,
#     'created_on': 1631638317,
#     'modified_on': 1643225450,
#     'url': 'https://www.behance.net/gallery/127383873/BRISE-SOLEIL-HOUSE',
#     'slug': 'BRISE-SOLEIL-HOUSE',
#     'privacy': 'public',
#     'fields': ['Architecture',
#      'Architecture Visualization',
#      'Architecture Photography'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/acaf69127383873.Y3JvcCw4MDgsNjMyLDAsMA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/acaf69127383873.Y3JvcCw4MDgsNjMyLDAsMA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/acaf69127383873.Y3JvcCw4MDgsNjMyLDAsMA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/acaf69127383873.Y3JvcCw4MDgsNjMyLDAsMA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/acaf69127383873.Y3JvcCw4MDgsNjMyLDAsMA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/acaf69127383873.Y3JvcCw4MDgsNjMyLDAsMA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/acaf69127383873.Y3JvcCw4MDgsNjMyLDAsMA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 460907719,
#       'first_name': 'RUBEN',
#       'last_name': 'MUEDRA',
#       'username': 'rubenmuedra',
#       'city': 'Valencia',
#       'state': '',
#       'country': 'Spain',
#       'location': 'Valencia, Spain',
#       'company': '⠀⠀⠀⠀⠀⠀⠀⠀⠀',
#       'occupation': 'ESTUDIO DE ARQUITECTURA',
#       'created_on': 1575882237,
#       'url': 'https://www.behance.net/rubenmuedra',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/34931c460907719.60f5873e7039e.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/34931c460907719.60f5873e7039e.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/34931c460907719.60f5873e7039e.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/34931c460907719.60f5873e7039e.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/34931c460907719.60f5873e7039e.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/34931c460907719.60f5873e7039e.jpg'},
#       'display_name': 'RUBEN MUEDRA',
#       'fields': ['Architecture',
#        'Architecture Photography',
#        'Architecture Visualization'],
#       'has_default_image': 0,
#       'website': 'rubenmuedra.com',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/e038fbc72282bf8ed6b48b7ef788206c/35c19a41-b726-4641-b7aa-9c4bf3edaf9d_rwc_-2x0x3200x334x3200.jpg?h=e282052e65525b5de9f212784e695c18',
#       'has_premium_access': False,
#       'stats': {'followers': 2653,
#        'following': 107,
#        'comments': 15,
#        'appreciations': 6972,
#        'views': 64912}}],
#     'stats': {'views': 2312, 'appreciations': 314, 'comments': 11},
#     'conceived_on': 1631577600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1643225450,
#       'site': {'id': 21,
#        'parent_id': 5,
#        'name': 'Architecture',
#        'key': 'architecture',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': 'architectureserved.com',
#        'url': 'https://www.behance.net/galleries/architecture/architecture',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 238, 'g': 233, 'b': 232}]},
#    {'id': 135527661,
#     'name': 'Lucky Land',
#     'published_on': 1642677954,
#     'created_on': 1642677849,
#     'modified_on': 1643139029,
#     'url': 'https://www.behance.net/gallery/135527661/Lucky-Land',
#     'slug': 'Lucky-Land',
#     'privacy': 'public',
#     'fields': ['Architecture'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/4abe42135527661.Y3JvcCwxMjU4LDk4MywyMDUsMA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/4abe42135527661.Y3JvcCwxMjU4LDk4MywyMDUsMA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/4abe42135527661.Y3JvcCwxMjU4LDk4MywyMDUsMA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/4abe42135527661.Y3JvcCwxMjU4LDk4MywyMDUsMA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/4abe42135527661.Y3JvcCwxMjU4LDk4MywyMDUsMA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/4abe42135527661.Y3JvcCwxMjU4LDk4MywyMDUsMA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/4abe42135527661.Y3JvcCwxMjU4LDk4MywyMDUsMA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 7540481,
#       'first_name': 'archimatika',
#       'last_name': 'LLC',
#       'username': 'archimatika',
#       'city': 'Kyiv',
#       'state': '',
#       'country': 'Ukraine',
#       'location': 'Kyiv, Ukraine',
#       'company': 'archimatika',
#       'occupation': 'architecture',
#       'created_on': 1408442953,
#       'url': 'https://www.behance.net/archimatika',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/7666dd7540481.5c17b23fd110e.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/7666dd7540481.5c17b23fd110e.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/7666dd7540481.5c17b23fd110e.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/7666dd7540481.5c17b23fd110e.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/7666dd7540481.5c17b23fd110e.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/7666dd7540481.5c17b23fd110e.png'},
#       'display_name': 'archimatika LLC',
#       'fields': ['Architecture', 'Landscape Design', 'Visual Effects'],
#       'has_default_image': 0,
#       'website': 'https://archimatika.com/',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/8d37f7a10405d2862af117774cf6dd5a/b6fff1d5-b775-4ece-8a1a-a3216a625ce1_rwc_-2x40x3200x330x3200.jpg?h=339ecd3dd9f72164c0743ffc217dd2c9',
#       'has_premium_access': False,
#       'stats': {'followers': 3272,
#        'following': 0,
#        'comments': 34,
#        'appreciations': 8067,
#        'views': 141033}}],
#     'stats': {'views': 2283, 'appreciations': 368, 'comments': 14},
#     'conceived_on': 1642636800,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1643139029,
#       'site': {'id': 141,
#        'parent_id': 5,
#        'name': 'Architecture Visualization',
#        'key': 'ArcV',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 54, 'g': 53, 'b': 50}]},
#    {'id': 134809473,
#     'name': 'ONYX',
#     'published_on': 1641922590,
#     'created_on': 1641857061,
#     'modified_on': 1643139025,
#     'url': 'https://www.behance.net/gallery/134809473/ONYX',
#     'slug': 'ONYX',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Interior Design', 'Furniture Design'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/c48d39134809473.Y3JvcCwxMTU0LDkwMywyOCw0MDA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/c48d39134809473.Y3JvcCwxMTU0LDkwMywyOCw0MDA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/c48d39134809473.Y3JvcCwxMTU0LDkwMywyOCw0MDA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/c48d39134809473.Y3JvcCwxMTU0LDkwMywyOCw0MDA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/c48d39134809473.Y3JvcCwxMTU0LDkwMywyOCw0MDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/c48d39134809473.Y3JvcCwxMTU0LDkwMywyOCw0MDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/c48d39134809473.Y3JvcCwxMTU0LDkwMywyOCw0MDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
# ...
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/171efc1721060.5ffedc36a4b87.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/171efc1721060.5ffedc36a4b87.jpg'},
#       'display_name': 'Dmitrii Tsyrenshchikov',
#       'fields': ['Interior Design', 'Architecture', 'Photography'],
#       'has_default_image': 0,
#       'website': 'Tsyrenshchikov.com',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/ecd4de9a6b5ccb050dd37a6249b35e01/ec2715dd-4a2e-431f-b14c-3fd331affffb_rwc_0x918x3072x326x3072.jpg?h=2f98064abed3eb17f68d76c715fc1aa9',
#       'has_premium_access': False,
#       'stats': {'followers': 8725,
#        'following': 28,
#        'comments': 3,
#        'appreciations': 20680,
#        'views': 244611}}],
#     'stats': {'views': 11763, 'appreciations': 1042, 'comments': 34},
#     'conceived_on': 1605657600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1606246227,
#       'site': {'id': 133,
#        'parent_id': 5,
#        'name': 'Architecture Photography',
#        'key': 'ArPh',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-photography',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'},
#      {'featured_on': 1642235423,
#       'site': {'id': 295,
#        'parent_id': 0,
#        'name': 'Photoshop',
#        'key': 'photoshop',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/photoshop.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/Photoshop',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/photoshop.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/photoshop@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/photoshop@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/Photoshop'}],
#     'colors': [{'r': 143, 'g': 143, 'b': 143}]},
#    {'id': 134916933,
#     'name': '1000 Trees | ShanghaiArchStory',
#     'published_on': 1642045364,
#     'created_on': 1641978722,
#     'modified_on': 1643034992,
#     'url': 'https://www.behance.net/gallery/134916933/1000-Trees-ShanghaiArchStory',
#     'slug': '1000-Trees-ShanghaiArchStory',
#     'privacy': 'public',
#     'fields': ['Photography', 'Architecture', 'Architecture Photography'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/d2c021134916933.Y3JvcCw0NjM3LDM2MjcsNDgyLDA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/d2c021134916933.Y3JvcCw0NjM3LDM2MjcsNDgyLDA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/d2c021134916933.Y3JvcCw0NjM3LDM2MjcsNDgyLDA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/d2c021134916933.Y3JvcCw0NjM3LDM2MjcsNDgyLDA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/d2c021134916933.Y3JvcCw0NjM3LDM2MjcsNDgyLDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/d2c021134916933.Y3JvcCw0NjM3LDM2MjcsNDgyLDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/d2c021134916933.Y3JvcCw0NjM3LDM2MjcsNDgyLDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 21348607,
#       'first_name': 'whyseeimage',
#       'last_name': '_',
#       'username': 'whyseeimage',
#       'city': 'Shanghai',
#       'state': '',
#       'country': 'China',
#       'location': 'Shanghai, China',
#       'company': '',
#       'occupation': 'Architectural Designer, Photographer',
#       'created_on': 1446841442,
#       'url': 'https://www.behance.net/whyseeimage',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/ac1e3521348607.5a61a6206c71a.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/ac1e3521348607.5a61a6206c71a.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/ac1e3521348607.5a61a6206c71a.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/ac1e3521348607.5a61a6206c71a.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/ac1e3521348607.5a61a6206c71a.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/ac1e3521348607.5a61a6206c71a.jpg'},
#       'display_name': 'whyseeimage _',
#       'fields': ['Photography', 'Architecture'],
#       'has_default_image': 0,
#       'website': 'whyseeimage.com',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/0d1823a41e5cd7b6880c4715c8e9225b/5f7e305c-eba1-4485-9c67-df69a1628dbb_rwc_0x1495x5472x764x5472.jpg?h=9e7c0a0607f0e1cccb913a8c18d845e7',
#       'has_premium_access': False,
#       'stats': {'followers': 4054,
#        'following': 104,
#        'comments': 49,
#        'appreciations': 10045,
#        'views': 120062}}],
#     'stats': {'views': 2957, 'appreciations': 308, 'comments': 17},
#     'conceived_on': 1641945600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1642195824,
#       'site': {'id': 133,
#        'parent_id': 5,
#        'name': 'Architecture Photography',
#        'key': 'ArPh',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-photography',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 93, 'g': 104, 'b': 101}]},
#    {'id': 108052649,
#     'name': 'Holiday Residence in Scandinavia',
#     'published_on': 1605773359,
#     'created_on': 1605710553,
#     'modified_on': 1642177816,
#     'url': 'https://www.behance.net/gallery/108052649/Holiday-Residence-in-Scandinavia',
#     'slug': 'Holiday-Residence-in-Scandinavia',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Visualization', 'Photography'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/f91e88108052649.Y3JvcCw0MjU5LDMzMzIsNDk1LDA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/f91e88108052649.Y3JvcCw0MjU5LDMzMzIsNDk1LDA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/f91e88108052649.Y3JvcCw0MjU5LDMzMzIsNDk1LDA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/f91e88108052649.Y3JvcCw0MjU5LDMzMzIsNDk1LDA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/f91e88108052649.Y3JvcCw0MjU5LDMzMzIsNDk1LDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/f91e88108052649.Y3JvcCw0MjU5LDMzMzIsNDk1LDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/f91e88108052649.Y3JvcCw0MjU5LDMzMzIsNDk1LDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 3952469,
#       'first_name': 'DIG',
#       'last_name': 'group',
#       'username': 'diggroup',
#       'city': 'Gdańsk',
#       'state': '',
#       'country': 'Poland',
#       'location': 'Gdańsk, Poland',
#       'company': 'DIG group',
#       'occupation': '',
#       'created_on': 1382982710,
#       'url': 'https://www.behance.net/diggroup',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/150dce3952469.5755457f2266c.png',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/150dce3952469.5755457f2266c.png',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/150dce3952469.5755457f2266c.png',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/150dce3952469.5755457f2266c.png',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/150dce3952469.5755457f2266c.png',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/150dce3952469.5755457f2266c.png'},
#       'display_name': 'DIG group',
#       'fields': ['Architecture', 'Digital Art', 'Interior Design'],
#       'has_default_image': 0,
#       'website': 'www.diggroup.pl',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/7e2a7c842e77d278a4cc4d2cd6e30e2f/831ca49e-ebe4-498f-8ecd-382d61cae7f7_rwc_0x1695x5001x830x5001.jpg?h=6bf8c53644373ddf6045802a5662fde6',
#       'has_premium_access': False,
#       'stats': {'followers': 4399,
#        'following': 1229,
#        'comments': 20,
#        'appreciations': 11362,
#        'views': 90998}}],
#     'stats': {'views': 10408, 'appreciations': 1199, 'comments': 43},
#     'conceived_on': 1605657600,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1606262414,
#       'site': {'id': 141,
#        'parent_id': 5,
#        'name': 'Architecture Visualization',
#        'key': 'ArcV',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'},
#      {'featured_on': 1642177816,
#       'site': {'id': 295,
#        'parent_id': 0,
#        'name': 'Photoshop',
#        'key': 'photoshop',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/photoshop.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/Photoshop',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/photoshop.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/photoshop@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/photoshop@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/Photoshop'}],
#     'colors': [{'r': 44, 'g': 50, 'b': 42}]},
#    {'id': 133813291,
#     'name': 'the house of two planes',
#     'published_on': 1640396233,
#     'created_on': 1640393550,
#     'modified_on': 1642177815,
#     'url': 'https://www.behance.net/gallery/133813291/the-house-of-two-planes',
#     'slug': 'the-house-of-two-planes',
#     'privacy': 'public',
#     'fields': ['Architecture', 'Art Direction', 'CGI'],
#     'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/84fdb2133813291.Y3JvcCwxNDM4LDExMjUsMjgxLDA.jpg',
#      '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/84fdb2133813291.Y3JvcCwxNDM4LDExMjUsMjgxLDA.jpg',
#      '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/84fdb2133813291.Y3JvcCwxNDM4LDExMjUsMjgxLDA.jpg',
#      '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/84fdb2133813291.Y3JvcCwxNDM4LDExMjUsMjgxLDA.jpg',
#      '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/84fdb2133813291.Y3JvcCwxNDM4LDExMjUsMjgxLDA.jpg',
#      'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/84fdb2133813291.Y3JvcCwxNDM4LDExMjUsMjgxLDA.jpg',
#      'max_808': 'https://mir-s3-cdn-cf.behance.net/projects/max_808/84fdb2133813291.Y3JvcCwxNDM4LDExMjUsMjgxLDA.jpg'},
#     'mature_content': 0,
#     'mature_access': 'allowed',
#     'owners': [{'id': 186238747,
#       'first_name': 'LUÍS',
#       'last_name': 'FERNANDO',
#       'username': 'luisarqui',
#       'city': 'Aracaju',
#       'state': '',
#       'country': 'Brazil',
#       'location': 'Aracaju, Brazil',
#       'company': '',
#       'occupation': 'Arquiteto, Artista 3D ',
#       'created_on': 1533058263,
#       'url': 'https://www.behance.net/luisarqui',
#       'images': {'50': 'https://mir-s3-cdn-cf.behance.net/user/50/750574186238747.60e460993741a.jpg',
#        '100': 'https://mir-s3-cdn-cf.behance.net/user/100/750574186238747.60e460993741a.jpg',
#        '115': 'https://mir-s3-cdn-cf.behance.net/user/115/750574186238747.60e460993741a.jpg',
#        '230': 'https://mir-s3-cdn-cf.behance.net/user/230/750574186238747.60e460993741a.jpg',
#        '138': 'https://mir-s3-cdn-cf.behance.net/user/138/750574186238747.60e460993741a.jpg',
#        '276': 'https://mir-s3-cdn-cf.behance.net/user/276/750574186238747.60e460993741a.jpg'},
#       'display_name': 'LUÍS FERNANDO',
#       'fields': ['Architecture', 'Interaction Design', 'Art Direction'],
#       'has_default_image': 0,
#       'website': '',
#       'banner_image_url': 'https://mir-s3-cdn-cf.behance.net/d0d2af847415dbbc21d96157fea81b31/9750a552-3885-4bb2-9f29-0a5d6d8e334d_rwc_0x55x3200x353x3200.jpg?h=93ad69d0421ac8785b2d380735198ea1',
#       'has_premium_access': False,
#       'stats': {'followers': 1932,
#        'following': 542,
#        'comments': 7,
#        'appreciations': 3980,
#        'views': 31034}}],
#     'stats': {'views': 3280, 'appreciations': 517, 'comments': 11},
#     'conceived_on': 1640390400,
#     'premium': 0,
#     'linked_asset_count': 0,
#     'linked_assets': [],
#     'features': [{'featured_on': 1642177815,
#       'site': {'id': 141,
#        'parent_id': 5,
#        'name': 'Architecture Visualization',
#        'key': 'ArcV',
#        'icon': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/square/1x/gallery-5.png?cb=264615658',
#        'app_icon': '?cb=264615658',
#        'domain': '',
#        'url': 'https://www.behance.net/galleries/architecture/architecture-visualization',
#        'ribbon': {'image': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/1x/architecture.png?cb=264615658',
#         'image_2x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/2x/architecture@2x.png?cb=264615658',
#         'image_3x': 'https://a5.behance.net/5497f513deb92a738c6b2cc14afd431ac727cd29/img/galleries/icons/ribbons/3x/architecture@3x.png?cb=264615658'}},
#       'url': 'https://www.behance.net/galleries/architecture'}],
#     'colors': [{'r': 170, 'g': 170, 'b': 88}]}]},
#  'suggestedTags': [],
#  'stockImages': [],
#  'stockImagesIsFetching': False,
#  'itemsPerPage': 48,
#  'nextOrdinal': 48,
#  'endCursor': '',
#  'isSafeBrowsing': True,
#  'showMature': False,
#  'metaContent': {'toolCard': None,
#   'schoolCard': None,
#   'csam': {'isCSAMViolation': False,
#    'title': '',
#    'description': '',
#    'reportingOption': '',
#    'helpResource': ''}},
#  'similarImagesSource': None,
#  'typeaheadResults': [],
#  'lastSearchTerm': '',
#  'nextPage': 'https://www.behance.net/search?sort=recommended&time=week&field=architecture&ordinal=48'}

# %%
# name
# first name
# last name
# user name
# country
# views
# appreciations
# comments
# url

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 10 pages to get 480 results)

# %% [markdown]
# #### Step 10 - Store Results in Excel
