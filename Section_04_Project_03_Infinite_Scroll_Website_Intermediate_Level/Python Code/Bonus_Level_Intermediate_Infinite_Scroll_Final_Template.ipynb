# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - Request & CURL

# %%
headers = {
    'authority': 'www.behance.net',
    'x-kl-ajax-request': 'Ajax_Request',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
    'accept': '*/*',
    'x-bcp': 'bfcbf186-ff42-4b9c-ba2a-8cf3ca2cb690',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-ch-ua': '^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
    'cookie': 'gk_suid=53192166; gki=^%^7B^%^22feature_stock_rail^%^22^%^3Afalse^%^7D; bcp=bfcbf186-ff42-4b9c-ba2a-8cf3ca2cb690; AMCVS_9E1005A551ED61CA0A490D45^%^40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; feds_privacy_consent=^{^\\^hasUserProvidedConsent^\\^:true,^\\^userHasCustomConsent^\\^:false^}; AMCV_9E1005A551ED61CA0A490D45^%^40AdobeOrg=870038026^%^7CMCMID^%^7C86810679775466113852269539934356177120^%^7CMCAAMLH-1643987617^%^7C4^%^7CMCAAMB-1643987617^%^7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y^%^7CMCOPTOUT-1643390017s^%^7CNONE^%^7CMCAID^%^7CNONE^%^7CMCCIDH^%^7C-869195863^%^7CvVersion^%^7C5.0.0; sign_up_prompt=true; s_sq=^%^5B^%^5BB^%^5D^%^5D; s_ppv=^[^%^22www.behance.net/^%^22^%^2C100^%^2C0^%^2C58510^%^2C330^%^2C663^%^2C1366^%^2C768^%^2C1^%^2C^%^22L^%^22^]; ilo0=true; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jan+28+2022+12^%^3A22^%^3A08+GMT-0300+(Hor^%^C3^%^A1rio+Padr^%^C3^%^A3o+de+Bras^%^C3^%^ADlia)&version=6.9.0&hosts=&consentId=1c61f996-0091-4d24-bfe5-2f09487b1522&interactionCount=1&landingPath=NotLandingPage&groups=C0001^%^3A1^%^2CC0002^%^3A1^%^2CC0003^%^3A1^%^2CC0004^%^3A1&AwaitingReconsent=false',
    'sec-gpc': '1',
}

params = (
    ('content', 'projects'),
    ('field', 'architecture'),
    ('ordinal', '0'),
)

response = requests.get('https://www.behance.net/search', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['search', 'creativeFields', 'tools', 'schools'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# result items (total: 48)
result_items = results_json['search']['content']['projects']

# %%
# Check the length
len(result_items)
# Out:
# 48

# %%
result_items[0]
# Out:
# {'id': 135571521,
#  'name': 'Albers House',
#  'published_on': 1642712265,
#  'created_on': 1642712180,
#  'modified_on': 1643400021,
#  'url': 'https://www.behance.net/gallery/135571521/Albers-House',
#  'slug': 'Albers-House',
#  'privacy': 'public',
#  'fields': ['Architecture', 'Interior Design'],
#  'covers': {'808': 'https://mir-s3-cdn-cf.behance.net/projects/808/c12d7d135571521.Y3JvcCwxNjM2LDEyODAsMTQxLDA.jpg',
#   '404': 'https://mir-s3-cdn-cf.behance.net/projects/404/c12d7d135571521.Y3JvcCwxNjM2LDEyODAsMTQxLDA.jpg',
#   '202': 'https://mir-s3-cdn-cf.behance.net/projects/202/c12d7d135571521.Y3JvcCwxNjM2LDEyODAsMTQxLDA.jpg',
#   '230': 'https://mir-s3-cdn-cf.behance.net/projects/230/c12d7d135571521.Y3JvcCwxNjM2LDEyODAsMTQxLDA.jpg',
#   '115': 'https://mir-s3-cdn-cf.behance.net/projects/115/c12d7d135571521.Y3JvcCwxNjM2LDEyODAsMTQxLDA.jpg',
#   'original': 'https://mir-s3-cdn-cf.behance.net/projects/original/c12d7d135571521.Y3JvcCwxNjM2LDEyODAsMTQxLDA.jpg',
# ...

# %%
# name
# first name
# last name
# user name
# country
# views
# appreciations
# comments
# url

# %%
# name
result_items[0]['name']
# Out:
# 'Albers House'

# %%
# first name
result_items[0]['owners'][0]['first_name']
# Out:
# 'RZLBD'

# %%
# last name
result_items[0]['owners'][0]['last_name']
# Out:
# '(Reza Aliabadi)'

# %%
# user name
result_items[0]['owners'][0]['username']
# Out:
# 'rzlbd'

# %%
# country
result_items[0]['owners'][0]['country']
# Out:
# 'Canada'

# %%
# views
result_items[0]['stats']['views']
# Out:
# 1801

# %%
# appreciations
result_items[0]['stats']['appreciations']
# Out:
# 274

# %%
# comments
result_items[0]['stats']['comments']
# Out:
# 17

# %%
# url
result_items[0]['url']
# Out:
# 'https://www.behance.net/gallery/135571521/Albers-House'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
name = []
first_name = []
last_name = []
user_name = []
country = []
views = []
appreciations = []
comments = []
url = []

for result in result_items:
    
    # name
    name.append(result['name'])
    
    # first name
    first_name.append(result['owners'][0]['first_name'])
    
    # last name
    last_name.append(result['owners'][0]['last_name'])
    
    # user name
    user_name.append(result['owners'][0]['username'])
    
    # country
    country.append(result['owners'][0]['country'])
    
    # views
    views.append(result['stats']['views'])
    
    # appreciations
    appreciations.append(result['stats']['appreciations'])
    
    # comments
    comments.append(result['stats']['comments'])
    
    # url
    url.append(result['url'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
df = pd.DataFrame({'name': name, 'first name': first_name, 'last name': last_name, 'user name': user_name,
                   'country': country, 'views': views, 'appreciations': appreciations, 'comments': comments, 'url': url})

# %%
df
# Out:
#                                              name      first name  \
# 0                                    Albers House           RZLBD
# 1            NIK MIRUS - MOTION, DESIGN AND SPACE              L'
# 2                         GRAPH + Faulkner Browns           GRAPH
# 3                                  monochrome 2.0  roomdesignburo
# 4                              An Audible Silence    Tomasz Artur
# 5                                     Golden Hour       Alexander
# 6                                      flow house         Ricardo
# 7   Mural For LaBel Valette Festival. France 2021        Katerina
# 8                              BRISE SOLEIL HOUSE           RUBEN
# 9                                      Lucky Land     archimatika
# 10                                           ONYX            URBA
# 11                                       Presence             Liz
# 12                                    Piera House            Fran
# ...

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 10 pages to get 480 results)

# %%
headers = {
    'authority': 'www.behance.net',
    'x-kl-ajax-request': 'Ajax_Request',
    'x-newrelic-id': 'VgUFVldbGwsFU1BRDwUBVw==',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
    'accept': '*/*',
    'x-bcp': 'bfcbf186-ff42-4b9c-ba2a-8cf3ca2cb690',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-ch-ua': '^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.behance.net/search/projects?field=architecture',
    'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
    'cookie': 'gk_suid=53192166; gki=^%^7B^%^22feature_stock_rail^%^22^%^3Afalse^%^7D; bcp=bfcbf186-ff42-4b9c-ba2a-8cf3ca2cb690; AMCVS_9E1005A551ED61CA0A490D45^%^40AdobeOrg=1; gpv=behance.net:search:projects; s_cc=true; feds_privacy_consent=^{^\\^hasUserProvidedConsent^\\^:true,^\\^userHasCustomConsent^\\^:false^}; AMCV_9E1005A551ED61CA0A490D45^%^40AdobeOrg=870038026^%^7CMCMID^%^7C86810679775466113852269539934356177120^%^7CMCAAMLH-1643987617^%^7C4^%^7CMCAAMB-1643987617^%^7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y^%^7CMCOPTOUT-1643390017s^%^7CNONE^%^7CMCAID^%^7CNONE^%^7CMCCIDH^%^7C-869195863^%^7CvVersion^%^7C5.0.0; sign_up_prompt=true; s_sq=^%^5B^%^5BB^%^5D^%^5D; s_ppv=^[^%^22www.behance.net/^%^22^%^2C100^%^2C0^%^2C58510^%^2C330^%^2C663^%^2C1366^%^2C768^%^2C1^%^2C^%^22L^%^22^]; ilo0=true; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jan+28+2022+12^%^3A22^%^3A08+GMT-0300+(Hor^%^C3^%^A1rio+Padr^%^C3^%^A3o+de+Bras^%^C3^%^ADlia)&version=6.9.0&hosts=&consentId=1c61f996-0091-4d24-bfe5-2f09487b1522&interactionCount=1&landingPath=NotLandingPage&groups=C0001^%^3A1^%^2CC0002^%^3A1^%^2CC0003^%^3A1^%^2CC0004^%^3A1&AwaitingReconsent=false',
    'sec-gpc': '1',
}

name = []
first_name = []
last_name = []
user_name = []
country = []
views = []
appreciations = []
comments = []
url = []

# scrape 10 pages

for i in range(0, 480, 48):
    params = (
        ('content', 'projects'),
        ('field', 'architecture'),
        ('ordinal', str(i)),
    )

    # response
    response = requests.get('https://www.behance.net/search', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # list of results
    result_items = results_json['search']['content']['projects']
        
    for result in result_items:
        
        # name
        name.append(result['name'])
        
        #first name
        first_name.append(result['owners'][0]['first_name'])
        
        # last name
        last_name.append(result['owners'][0]['last_name'])
        
        # user name
        user_name.append(result['owners'][0]['username'])
        
        # country
        country.append(result['owners'][0]['country'])
        
        # views
        views.append(result['stats']['views'])
        
        # appreciations
        appreciations.append(result['stats']['appreciations'])
        
        # comments
        comments.append(result['stats']['comments'])
        
        # url
        url.append(result['url'])

# %%
df = pd.DataFrame({'name': name, 'first name': first_name, 'last name': last_name, 'user name': user_name, 
                   'country': country, 'views': views, 'appreciations': appreciations, 'comments': comments, 'url': url})

# %%
df
# Out:
#                                      name       first name        last name  \
# 0                            Albers House            RZLBD  (Reza Aliabadi)
# 1    NIK MIRUS - MOTION, DESIGN AND SPACE               L'             ÉLOI
# 2                 GRAPH + Faulkner Browns            GRAPH    Visual Studio
# 3                          monochrome 2.0   roomdesignburo                _
# 4                      An Audible Silence     Tomasz Artur            Bolek
# ..                                    ...              ...              ...
# 475                          VILLAGGIO II  Distance Studio      Consultants
# 476        4CITY space in Odessa, Ukraine            slava           balbek
# 477                     Maui Travel Diary           cybèle           design
# 478              Underground House Plan B           Makhno           Studio
# 479                Hamilton villa. NY USA           Mykola          Mondich
#
# ...

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
df.to_csv('pictures_multiple_pages.xlsx', index=False)
