# %% [markdown]
# # Part 1 - Truecar.com - New York

# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# #### Step 2 - Python Request

# %%
headers = {
    'authority': 'www.truecar.com',
    'x-kl-ajax-request': 'Ajax_Request',
    'accept': 'application/json, text/plain, */*',
    'x-xsrf-token': 'vBBPvXrx5afTIReNLMu5fvLfls2MufDA1E9BJ1SFwEVoV19sf8viLMISBh7nbdkXG0DyYJSVXo1AnIdaOBudYA==',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
    'sec-ch-ua': '^\\^',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
    'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
    'cookie': 'tcip=189.102.132.18; tc_v=7c33cc87-a35a-44e0-b73c-7dfc556782dd; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=V7Vhf0fXKvdLlQ32pv5F8hL5E31SmiqMCqDi9hRupKI; referrer=ZTC0000000; u=rBEABmH6jEa6GAATFgMuAg==; tealium_test_field=Test_C; _gid=GA1.2.228270129.1643809867; _fbp=fb.1.1643809867174.2005869532; _scid=d783253c-9a06-424a-9230-d7e45930444b; _gcl_au=1.1.783512904.1643809868; _pin_unauth=dWlkPVkyUmxORFk0TnpRdFpqQm1ZaTAwTVdWaExUZzROV0l0WkRrMll6YzVaRFEwWm1Fdw; _clck=7z2fbt^|1^|eyn^|0; fs_uid=rs.fullstory.com^#G5Y78^#5292993677058048:6353595253088256^#20d87e0a^#/1675345867; g_state=^{^\\^i_p^\\^:1643817231228,^\\^i_l^\\^:1^}; __olapicU=1643810055990; _ga=GA1.1.1391263899.1643809867; _uetsid=2bc36740842f11eca0137519ca8ebf04; _uetvid=2bc38750842f11ecbae419fce02090de; QSI_HistorySession=https^%^3A^%^2F^%^2Fwww.truecar.com^%^2F~1643809870563^%^7Chttps^%^3A^%^2F^%^2Fwww.truecar.com^%^2Fused-cars-for-sale^%^2F~1643810085219; user_zip_code_new-york-ny=10001; capselaPreferredPostalCode=10001; XSRF-TOKEN=vBBPvXrx5afTIReNLMu5fvLfls2MufDA1E9BJ1SFwEVoV19sf8viLMISBh7nbdkXG0DyYJSVXo1AnIdaOBudYA^%^3D^%^3D; _abp_backend_session=YTNyR05lNGtOUmFaYVZsK0ZFajI1SGFNTWdaZ24wd0luZ002L0l0TjJkTUd3S1NMdzYrNWU0YmRDckhSa3dxbVhCZHdQcUZybndRaS9ScXY0RFEzNlVBZ3h2QmdiM3pRQkNobFZQejB0dVpxSXY3SUk3VHpKUzFBY3piNGc4TnFhOEZkM1NPalo0Zk5PdDBKQlZQWEp3PT0tLXI3dGZFMDJrMm90aThGMlNxU1JQbmc9PQ^%^3D^%^3D--0a80014988ec1bd87dcb08b2edc6460761a4a6f6; _ga_XD4TBVCD03=GS1.1.1643809867.1.1.1643810284.0; _clsk=3kcpc7^|1643810284337^|7^|1^|a.clarity.ms/collect; _dd_s=rum=0&expire=1643811608462; utag_main=v_id:017ebab3fb39001ee5d1c2d2d95505072001806a0086e^$_sn:1^$_se:16^$_ss:0^$_st:1643812508472^$ses_id:1643809864507^%^3Bexp-session^$_pn:2^%^3Bexp-session^$dc_visit:1^$dc_event:15^%^3Bexp-session^$dc_region:us-east-1^%^3Bexp-session',
    'if-none-match': 'W/^\\^5cbbc71cbf040729d62f7203bc797c40^\\^',
}

params = (
    ('city', 'new-york'),
    ('collapse', 'true'),
    ('fallback', 'true'),
    ('include_incentives', 'true'),
    ('include_targeted_incentives', 'true'),
    ('new_or_used', 'u'),
    ('page', '1'),
    ('per_page', '30'),
    ('postal_code', '10001'),
    ('search_event', 'true'),
    ('sort^\\[^\\]', 'best_match'),
    ('sponsored', 'true'),
    ('state', 'ny'),
)

response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['listings', 'page', 'per_page', 'total', 'fallback', 'fallback_step', 'refine_parameters', 'display', 'list_price', 'sponsored_listings', 'location'])

# %% [markdown]
# #### Step 6 - Find your Data

# %% [markdown]
# Necessary data
# - brand
# - model
# - mileage
# - year
# - price

# %%
len(results_json['listings'])
# Out:
# 30

# %%
result_items = results_json['listings']

# %%
# brand
result_items[0]['vehicle']['make']
# Out:
# 'Mercedes-Benz'

# %%
# model
result_items[0]['vehicle']['model']
# Out:
# 'GLE'

# %%
# mileage
result_items[0]['vehicle']['mileage']
# Out:
# 46542

# %%
# year
result_items[0]['vehicle']['year']
# Out:
# 2018

# %%
# price
result_items[0]['pricing']['list_price']
# Out:
# 39901

# %% [markdown]
# #### Step 7 - Put everything together & For-Loop

# %%
brand_ny = []
model_ny = []
mileage_ny = []
year_ny = []
price_ny = []

for result in result_items:
    
    # brand
    brand_ny.append(result['vehicle']['make'])
    
    # model
    model_ny.append(result['vehicle']['model'])
    
    # mileage
    mileage_ny.append(result['vehicle']['mileage'])
    
    # year
    year_ny.append(result['vehicle']['year'])
    
    # price
    price_ny.append(result['pricing']['list_price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
df_ny_single = pd.DataFrame({'Brand': brand_ny, 'Model': model_ny, 'Mileage': mileage_ny, 'Year': year_ny,
                             'Price': price_ny})

# %%
df_ny_single
# Out:
#             Brand           Model  Mileage  Year   Price
# 0   Mercedes-Benz             GLE    46542  2018   39901
# 1   Mercedes-Benz             GLC    31021  2019   37904
# 2   Mercedes-Benz         C-Class    41829  2018   31901
# 3   Mercedes-Benz         C-Class    20685  2018   32903
# 4   Mercedes-Benz             GLB     7279  2021   45035
# 5           Lexus              RX    30429  2019   38569
# 6         Ferrari  612 Scaglietti    15104  2005  110500
# 7   Mercedes-Benz             CLA    41742  2018   26906
# 8   Mercedes-Benz             GLC    18386  2019   39903
# 9   Mercedes-Benz             GLE    13753  2019   71903
# 10  Mercedes-Benz         S-Class   115225  2008   11995
# 11         Nissan           Rogue    45032  2018   17995
# 12  Mercedes-Benz             CLA    31553  2018   27903
# 13          Honda          Accord   112040  2017   17595
# 14  Mercedes-Benz             GLC    38815  2019   38905
# ...

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: ~5000results)

# %%
brand_ny = []
model_ny = []
mileage_ny = []
year_ny = []
price_ny = []

for i in range(1, 170):
    
    headers = {
        'authority': 'www.truecar.com',
        'x-kl-ajax-request': 'Ajax_Request',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'vBBPvXrx5afTIReNLMu5fvLfls2MufDA1E9BJ1SFwEVoV19sf8viLMISBh7nbdkXG0DyYJSVXo1AnIdaOBudYA==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
        'sec-ch-ua': '^\\^',
        'sec-ch-ua-platform': '^\\^Windows^\\^',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
        'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
        'cookie': 'tcip=189.102.132.18; tc_v=7c33cc87-a35a-44e0-b73c-7dfc556782dd; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=V7Vhf0fXKvdLlQ32pv5F8hL5E31SmiqMCqDi9hRupKI; referrer=ZTC0000000; u=rBEABmH6jEa6GAATFgMuAg==; tealium_test_field=Test_C; _gid=GA1.2.228270129.1643809867; _fbp=fb.1.1643809867174.2005869532; _scid=d783253c-9a06-424a-9230-d7e45930444b; _gcl_au=1.1.783512904.1643809868; _pin_unauth=dWlkPVkyUmxORFk0TnpRdFpqQm1ZaTAwTVdWaExUZzROV0l0WkRrMll6YzVaRFEwWm1Fdw; _clck=7z2fbt^|1^|eyn^|0; fs_uid=rs.fullstory.com^#G5Y78^#5292993677058048:6353595253088256^#20d87e0a^#/1675345867; g_state=^{^\\^i_p^\\^:1643817231228,^\\^i_l^\\^:1^}; __olapicU=1643810055990; _ga=GA1.1.1391263899.1643809867; _uetsid=2bc36740842f11eca0137519ca8ebf04; _uetvid=2bc38750842f11ecbae419fce02090de; QSI_HistorySession=https^%^3A^%^2F^%^2Fwww.truecar.com^%^2F~1643809870563^%^7Chttps^%^3A^%^2F^%^2Fwww.truecar.com^%^2Fused-cars-for-sale^%^2F~1643810085219; user_zip_code_new-york-ny=10001; capselaPreferredPostalCode=10001; XSRF-TOKEN=vBBPvXrx5afTIReNLMu5fvLfls2MufDA1E9BJ1SFwEVoV19sf8viLMISBh7nbdkXG0DyYJSVXo1AnIdaOBudYA^%^3D^%^3D; _abp_backend_session=YTNyR05lNGtOUmFaYVZsK0ZFajI1SGFNTWdaZ24wd0luZ002L0l0TjJkTUd3S1NMdzYrNWU0YmRDckhSa3dxbVhCZHdQcUZybndRaS9ScXY0RFEzNlVBZ3h2QmdiM3pRQkNobFZQejB0dVpxSXY3SUk3VHpKUzFBY3piNGc4TnFhOEZkM1NPalo0Zk5PdDBKQlZQWEp3PT0tLXI3dGZFMDJrMm90aThGMlNxU1JQbmc9PQ^%^3D^%^3D--0a80014988ec1bd87dcb08b2edc6460761a4a6f6; _ga_XD4TBVCD03=GS1.1.1643809867.1.1.1643810284.0; _clsk=3kcpc7^|1643810284337^|7^|1^|a.clarity.ms/collect; _dd_s=rum=0&expire=1643811608462; utag_main=v_id:017ebab3fb39001ee5d1c2d2d95505072001806a0086e^$_sn:1^$_se:16^$_ss:0^$_st:1643812508472^$ses_id:1643809864507^%^3Bexp-session^$_pn:2^%^3Bexp-session^$dc_visit:1^$dc_event:15^%^3Bexp-session^$dc_region:us-east-1^%^3Bexp-session',
        'if-none-match': 'W/^\\^5cbbc71cbf040729d62f7203bc797c40^\\^',
    }

    params = (
        ('city', 'new-york'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '10001'),
        ('search_event', 'true'),
        ('sort^\\[^\\]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ny'),
    )
    
    # response
    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (30 items per page)
    result_items = results_json['listings']
    
    for result in result_items:
        
        # barnd
        brand_ny.append(result['vehicle']['make'])
        
        # model
        model_ny.append(result['vehicle']['model'])
        
        # mileage
        mileage_ny.append(result['vehicle']['mileage'])
        
        # year
        year_ny.append(result['vehicle']['year'])
        
        # price
        price_ny.append(result['pricing']['list_price'])

# %%
df_my_single = pd.DataFrame({'Brand': brand_ny, 'Model': model_ny, 'Mileage': mileage_ny, 'Year': year_ny, 
                             'Price': price_ny})

# %%
df_ny_single
# Out:
#             Brand           Model  Mileage  Year   Price
# 0   Mercedes-Benz             GLE    46542  2018   39901
# 1   Mercedes-Benz             GLC    31021  2019   37904
# 2   Mercedes-Benz         C-Class    41829  2018   31901
# 3   Mercedes-Benz         C-Class    20685  2018   32903
# 4   Mercedes-Benz             GLB     7279  2021   45035
# 5           Lexus              RX    30429  2019   38569
# 6         Ferrari  612 Scaglietti    15104  2005  110500
# 7   Mercedes-Benz             CLA    41742  2018   26906
# 8   Mercedes-Benz             GLC    18386  2019   39903
# 9   Mercedes-Benz             GLE    13753  2019   71903
# 10  Mercedes-Benz         S-Class   115225  2008   11995
# 11         Nissan           Rogue    45032  2018   17995
# 12  Mercedes-Benz             CLA    31553  2018   27903
# 13          Honda          Accord   112040  2017   17595
# 14  Mercedes-Benz             GLC    38815  2019   38905
# ...

# %%
df_ny_single.to_csv('output_5k.xlsx', index=False)

# %% [markdown]
# # Part 2 - Truecar.com - San Francisco

# %%
brand_sf = []
model_sf = []
mileage_sf = []
year_sf = []
price_sf = []

for i in range(1, 170):    

    headers = {
        'authority': 'www.truecar.com',
        'x-kl-ajax-request': 'Ajax_Request',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': '8I34zR6Xcx3dsnVKJbFwl51e56xi1QFQOcOwlYcgpBskyugcG610lsyBZNnuFxD+dMGDAXr5rx2tEHbo6775Pg==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36',
        'sec-ch-ua': '^\\^',
        'sec-ch-ua-platform': '^\\^Windows^\\^',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-san-francisco-ca/',
        'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
        'cookie': 'tcip=189.102.132.18; tc_v=7c33cc87-a35a-44e0-b73c-7dfc556782dd; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=V7Vhf0fXKvdLlQ32pv5F8hL5E31SmiqMCqDi9hRupKI; referrer=ZTC0000000; u=rBEABmH6jEa6GAATFgMuAg==; tealium_test_field=Test_C; _gid=GA1.2.228270129.1643809867; _fbp=fb.1.1643809867174.2005869532; _scid=d783253c-9a06-424a-9230-d7e45930444b; _gcl_au=1.1.783512904.1643809868; _pin_unauth=dWlkPVkyUmxORFk0TnpRdFpqQm1ZaTAwTVdWaExUZzROV0l0WkRrMll6YzVaRFEwWm1Fdw; _clck=7z2fbt^|1^|eyn^|0; g_state=^{^\\^i_p^\\^:1643817231228,^\\^i_l^\\^:1^}; __olapicU=1643810055990; _ga=GA1.1.1391263899.1643809867; _uetsid=2bc36740842f11eca0137519ca8ebf04; _uetvid=2bc38750842f11ecbae419fce02090de; QSI_HistorySession=https^%^3A^%^2F^%^2Fwww.truecar.com^%^2F~1643809870563^%^7Chttps^%^3A^%^2F^%^2Fwww.truecar.com^%^2Fused-cars-for-sale^%^2F~1643810085219; user_zip_code_new-york-ny=10001; fs_uid=rs.fullstory.com^#G5Y78^#5292993677058048:6315434541015040^#20d87e0a^#/1675345867; user_zip_code_san-francisco-ca=94102; capselaPreferredPostalCode=94102; XSRF-TOKEN=8I34zR6Xcx3dsnVKJbFwl51e56xi1QFQOcOwlYcgpBskyugcG610lsyBZNnuFxD^%^2BdMGDAXr5rx2tEHbo6775Pg^%^3D^%^3D; _abp_backend_session=Mmh0K1BmMWxrZFhxLzYwMStvOGVvOWtmQ2pmNElmYmlTbHBmUmlteVdWc1lScFFHVFFNWENZZU1yejVuYXo3TVNWeGdicSthdkh6VzZENVd4WGovNzB0VXRxZmg4RnNUUy9yM0RHOXR2NUhVOGVXZHZFdGg4Skx2RU5GRVhYQ0NjY3d2aFRNSmxySnRDNHJBQzN0eXFBPT0tLS8rRzhBNUxXWWVLMXZ0M1hhRHBhWEE9PQ^%^3D^%^3D--101f8c0aeeca456c2a6afd86c13e6166e3bf80d1; _ga_XD4TBVCD03=GS1.1.1643822424.2.1.1643822448.0; _clsk=lda9v3^|1643822448753^|8^|1^|a.clarity.ms/collect; _dd_s=rum=0&expire=1643823369980; utag_main=v_id:017ebab3fb39001ee5d1c2d2d95505072001806a0086e^$_sn:2^$_se:11^$_ss:0^$_st:1643824269985^$dc_visit:2^$ses_id:1643822425078^%^3Bexp-session^$_pn:1^%^3Bexp-session^$dc_event:11^%^3Bexp-session^$dc_region:us-east-1^%^3Bexp-session',
    }

    params = (
        ('city', 'san-francisco'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '94102'),
        ('search_event', 'true'),
        ('sort^\\[^\\]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ca'),
    )
    
    # response
    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (30 items per page)
    result_items = results_json['listings']
    
    for result in result_items:
        
        # brand
        brand_sf.append(result['vehicle']['make'])
        
        # model
        model_sf.append(result['vehicle']['model'])
        
        # mileage
        mileage_sf.append(result['vehicle']['mileage'])
        
        # year
        year_sf.append(result['vehicle']['year'])
        
        # price
        price_sf.append(result['pricing']['list_price'])

# %%
df_sf_single = pd.DataFrame({'Brand': brand_sf, 'Model': model_sf, 'Mileage': mileage_sf, 'Year': year_sf,
                             'Price': price_sf})

# %%
df_sf_single
# Out:
#               Brand     Model  Mileage  Year    Price
# 0               BMW  3 Series    30601  2018  28495.0
# 1            Nissan    Sentra    35236  2019  19995.0
# 2               BMW  3 Series    22314  2018  36495.0
# 3               BMW  3 Series    26977  2018  29495.0
# 4     Mercedes-Benz   C-Class    13169  2018  33495.0
# ...             ...       ...      ...   ...      ...
# 5065         Nissan    Murano    26940  2020  36998.0
# 5066     Volkswagen    Tiguan    20925  2019  24990.0
# 5067         Nissan    Sentra    24632  2019  22499.0
# 5068           MINI   Hardtop    14957  2019  27990.0
# 5069          Dodge   Charger    34101  2019  37998.0
#
# [5070 rows x 5 columns]

# %%
df_sf_single.to_csv('output_5k.xlsx', index=False)

# %% [markdown]
# # Part 3 - Combine Data & Connect to Database - PostgreSQL

# %%
# merge dataframes
merged_dataframes = pd.concat([df_ny_single, df_sf_single], ignore_index=True)

# %%
merged_dataframes['Price'].astype('Int64')
# Out:
# 0       39901
# 1       37904
# 2       31901
# 3       32903
# 4       45035
#         ...
# 5095    36998
# 5096    24990
# 5097    22499
# 5098    27990
# 5099    37998
# Name: Price, Length: 5100, dtype: Int64

# %%
# outuput update dataframe
merged_dataframes
# Out:
#               Brand    Model  Mileage  Year    Price
# 0     Mercedes-Benz      GLE    46542  2018  39901.0
# 1     Mercedes-Benz      GLC    31021  2019  37904.0
# 2     Mercedes-Benz  C-Class    41829  2018  31901.0
# 3     Mercedes-Benz  C-Class    20685  2018  32903.0
# 4     Mercedes-Benz      GLB     7279  2021  45035.0
# ...             ...      ...      ...   ...      ...
# 5095         Nissan   Murano    26940  2020  36998.0
# 5096     Volkswagen   Tiguan    20925  2019  24990.0
# 5097         Nissan   Sentra    24632  2019  22499.0
# 5098           MINI  Hardtop    14957  2019  27990.0
# 5099          Dodge  Charger    34101  2019  37998.0
#
# [5100 rows x 5 columns]

# %%
merged_dataframes.to_csv('merged_dataframes.xlsx', index=False)

# %%
engine = create_engine('postgresql://postgres:138699@localhost:5432')
merged_dataframes.to_sql('cars_results', engine)
# Out:
# 100
